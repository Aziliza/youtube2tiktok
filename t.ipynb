# %%
'''
Author: qianyu
Date: 2026-01-20 15:48:52
LastEditTime: 2026-01-20 16:41:06
'''
import os
import yt_dlp

def get_download_options(url, cookies_file):
    """
    获取YouTube视频的所有可下载格式列表
    :param url: YouTube视频链接
    :param cookies_file: cookies文件路径
    :return: 视频信息字典（包含所有格式），或None
    """
    try:
        ydl_opts = {
            'quiet': True,          # 静默模式，只获取信息不下载
            'no_warnings': True,
            'cookiefile': cookies_file,
            'skip_download': True,  # 跳过实际下载，仅获取信息
        }

        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            # 提取视频信息（包含所有可下载格式）
            video_info = ydl.extract_info(url, download=False)
            return video_info

    except Exception as e:
        print(f"获取下载选项失败：{str(e)}")
        return None

def print_download_options(video_info):
    """
    格式化打印所有可下载的视频/音频选项
    :param video_info: 视频信息字典
    """
    if not video_info or 'formats' not in video_info:
        print("未获取到可下载的格式信息")
        return

    print("\n" + "="*80)
    print(f"视频标题：{video_info.get('title', '未知')}")
    print(f"视频ID：{video_info.get('id', '未知')}")
    print("="*80)
    print("可下载格式列表（格式ID | 类型 | 分辨率/码率 | 扩展名 | 大小）：")
    print("-"*80)

    # 遍历所有格式，筛选并格式化输出
    for fmt in video_info['formats']:
        # 跳过不需要的格式（比如m3u8流媒体）
        if fmt.get('vcodec') == 'none' and fmt.get('acodec') == 'none':
            continue
        
        # 基础信息
        fmt_id = fmt.get('format_id', '未知')
        ext = fmt.get('ext', '未知')
        filesize = fmt.get('filesize') or fmt.get('filesize_approx')
        filesize_str = f"{filesize/1024/1024:.2f} MB" if filesize else "未知"
        
        # 视频/音频类型判断
        if fmt.get('vcodec') != 'none' and fmt.get('acodec') != 'none':
            type_str = "视频+音频"
            resolution = fmt.get('resolution', '未知') or f"{fmt.get('width', '?')}x{fmt.get('height', '?')}"
        elif fmt.get('vcodec') != 'none':
            type_str = "仅视频"
            resolution = fmt.get('resolution', '未知') or f"{fmt.get('width', '?')}x{fmt.get('height', '?')}"
        else:
            type_str = "仅音频"
            resolution = f"{fmt.get('abr', '?')} kbps"
        
        # 打印一行
        print(f"{fmt_id:>6} | {type_str:<8} | {resolution:<12} | {ext:<6} | {filesize_str}")

    print("="*80)

def download_youtube_video(url, cookies_file, format_id=None):
    """
    使用yt-dlp下载YouTube视频，带cookies认证，可指定格式
    :param url: YouTube视频链接
    :param cookies_file: cookies文件路径
    :param format_id: 指定下载的格式ID（None则下载默认最佳格式）
    """
    try:
        # 创建输出目录（如果不存在）
        output_dir = 'data/raw_videos'
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
            print(f"创建输出目录：{output_dir}")

        # 下载配置
        ydl_opts = {
            'outtmpl': os.path.join(output_dir, '%(title)s_%(id)s.%(ext)s'),  # 输出路径和文件名格式
            'quiet': False,  # 显示下载进度
            'no_warnings': True,  # 屏蔽警告
            'cookiefile': cookies_file,  # 使用cookies文件
        }

        # 如果指定了格式ID，添加格式筛选
        if format_id:
            ydl_opts['format'] = format_id
            print(f"指定下载格式ID：{format_id}")

        # 执行下载
        print(f"\n正在下载视频：{url}")
        print(f"使用cookies文件：{cookies_file}")
        
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([url])
            
        print("\n下载完成！文件保存至：", output_dir)
        return True
        
    except Exception as e:
        print(f"\n下载失败：{str(e)}")
        return False

if __name__ == "__main__":
    # 测试视频URL
    test_url = "https://www.youtube.com/shorts/U9vZjYmt81c"
    
    # cookies文件路径
    cookies_path = os.path.join("config", "cookies.txt")
    
    # 检查cookies文件是否存在
    if not os.path.exists(cookies_path):
        print(f"错误：cookies文件不存在 → {cookies_path}")
        print("请确保您已经在config目录下放置了cookies.txt文件")
    else:
        # 1. 获取并打印所有可下载选项
        video_info = get_download_options(test_url, cookies_path)
        if video_info:
            print_download_options(video_info)
            
            # 2. 可选：让用户输入格式ID进行下载（注释掉则自动下载最佳格式）
            user_choice = input("\n请输入要下载的格式ID（直接回车下载默认最佳格式）：").strip()
            format_id = user_choice if user_choice else None
            
            # 3. 执行下载
            download_youtube_video(test_url, cookies_path, format_id)
# Out:
# ================================================================================
# 视频标题：knowledge Distillation
# 视频ID：U9vZjYmt81c
# ================================================================================
# 可下载格式列表（格式ID | 类型 | 分辨率/码率 | 扩展名 | 大小）：
# --------------------------------------------------------------------------------
#   91-0 | 视频+音频    | 144x256      | mp4    | 未知
#   91-1 | 视频+音频    | 144x256      | mp4    | 未知
#   91-2 | 视频+音频    | 144x256      | mp4    | 未知
#   91-3 | 视频+音频    | 144x256      | mp4    | 未知
#   91-4 | 视频+音频    | 144x256      | mp4    | 未知
#   91-5 | 视频+音频    | 144x256      | mp4    | 未知
#   91-6 | 视频+音频    | 144x256      | mp4    | 未知
#   91-7 | 视频+音频    | 144x256      | mp4    | 未知
#   91-8 | 视频+音频    | 144x256      | mp4    | 未知
#   91-9 | 视频+音频    | 144x256      | mp4    | 未知
#  91-10 | 视频+音频    | 144x256      | mp4    | 未知
#  91-11 | 视频+音频    | 144x256      | mp4    | 未知
#  91-12 | 视频+音频    | 144x256      | mp4    | 未知
#  91-13 | 视频+音频    | 144x256      | mp4    | 未知
#   92-0 | 视频+音频    | 240x426      | mp4    | 未知
#   92-1 | 视频+音频    | 240x426      | mp4    | 未知
#   92-2 | 视频+音频    | 240x426      | mp4    | 未知
#   92-3 | 视频+音频    | 240x426      | mp4    | 未知
#   92-4 | 视频+音频    | 240x426      | mp4    | 未知
#   92-5 | 视频+音频    | 240x426      | mp4    | 未知
#   92-6 | 视频+音频    | 240x426      | mp4    | 未知
#   92-7 | 视频+音频    | 240x426      | mp4    | 未知
#   92-8 | 视频+音频    | 240x426      | mp4    | 未知
#   92-9 | 视频+音频    | 240x426      | mp4    | 未知
#  92-10 | 视频+音频    | 240x426      | mp4    | 未知
#  92-11 | 视频+音频    | 240x426      | mp4    | 未知
#  92-12 | 视频+音频    | 240x426      | mp4    | 未知
#  92-13 | 视频+音频    | 240x426      | mp4    | 未知
#   93-0 | 视频+音频    | 360x640      | mp4    | 未知
#   93-1 | 视频+音频    | 360x640      | mp4    | 未知
#   93-2 | 视频+音频    | 360x640      | mp4    | 未知
#   93-3 | 视频+音频    | 360x640      | mp4    | 未知
#   93-4 | 视频+音频    | 360x640      | mp4    | 未知
#   93-5 | 视频+音频    | 360x640      | mp4    | 未知
#   93-6 | 视频+音频    | 360x640      | mp4    | 未知
#   93-7 | 视频+音频    | 360x640      | mp4    | 未知
#   93-8 | 视频+音频    | 360x640      | mp4    | 未知
#   93-9 | 视频+音频    | 360x640      | mp4    | 未知
#  93-10 | 视频+音频    | 360x640      | mp4    | 未知
#  93-11 | 视频+音频    | 360x640      | mp4    | 未知
#  93-12 | 视频+音频    | 360x640      | mp4    | 未知
#  93-13 | 视频+音频    | 360x640      | mp4    | 未知
#   94-0 | 视频+音频    | 480x854      | mp4    | 未知
#   94-1 | 视频+音频    | 480x854      | mp4    | 未知
#   94-2 | 视频+音频    | 480x854      | mp4    | 未知
#   94-3 | 视频+音频    | 480x854      | mp4    | 未知
#   94-4 | 视频+音频    | 480x854      | mp4    | 未知
#   94-5 | 视频+音频    | 480x854      | mp4    | 未知
#   94-6 | 视频+音频    | 480x854      | mp4    | 未知
#   94-7 | 视频+音频    | 480x854      | mp4    | 未知
#   94-8 | 视频+音频    | 480x854      | mp4    | 未知
#   94-9 | 视频+音频    | 480x854      | mp4    | 未知
#  94-10 | 视频+音频    | 480x854      | mp4    | 未知
#  94-11 | 视频+音频    | 480x854      | mp4    | 未知
#  94-12 | 视频+音频    | 480x854      | mp4    | 未知
#  94-13 | 视频+音频    | 480x854      | mp4    | 未知
#  300-0 | 视频+音频    | 720x1280     | mp4    | 未知
#  300-1 | 视频+音频    | 720x1280     | mp4    | 未知
#  300-2 | 视频+音频    | 720x1280     | mp4    | 未知
#  300-3 | 视频+音频    | 720x1280     | mp4    | 未知
#  300-4 | 视频+音频    | 720x1280     | mp4    | 未知
#  300-5 | 视频+音频    | 720x1280     | mp4    | 未知
#  300-6 | 视频+音频    | 720x1280     | mp4    | 未知
#  300-7 | 视频+音频    | 720x1280     | mp4    | 未知
#  300-8 | 视频+音频    | 720x1280     | mp4    | 未知
#  300-9 | 视频+音频    | 720x1280     | mp4    | 未知
# 300-10 | 视频+音频    | 720x1280     | mp4    | 未知
# 300-11 | 视频+音频    | 720x1280     | mp4    | 未知
# 300-12 | 视频+音频    | 720x1280     | mp4    | 未知
# 300-13 | 视频+音频    | 720x1280     | mp4    | 未知
#  301-0 | 视频+音频    | 1080x1920    | mp4    | 未知
#  301-1 | 视频+音频    | 1080x1920    | mp4    | 未知
#  301-2 | 视频+音频    | 1080x1920    | mp4    | 未知
#  301-3 | 视频+音频    | 1080x1920    | mp4    | 未知
#  301-4 | 视频+音频    | 1080x1920    | mp4    | 未知
#  301-5 | 视频+音频    | 1080x1920    | mp4    | 未知
#  301-6 | 视频+音频    | 1080x1920    | mp4    | 未知
#  301-7 | 视频+音频    | 1080x1920    | mp4    | 未知
#  301-8 | 视频+音频    | 1080x1920    | mp4    | 未知
#  301-9 | 视频+音频    | 1080x1920    | mp4    | 未知
# 301-10 | 视频+音频    | 1080x1920    | mp4    | 未知
# 301-11 | 视频+音频    | 1080x1920    | mp4    | 未知
# 301-12 | 视频+音频    | 1080x1920    | mp4    | 未知
# 301-13 | 视频+音频    | 1080x1920    | mp4    | 未知
# ================================================================================
# 指定下载格式ID：301-13
#
# 正在下载视频：https://www.youtube.com/shorts/U9vZjYmt81c
# 使用cookies文件：config\cookies.txt
# [youtube] Extracting URL: https://www.youtube.com/shorts/U9vZjYmt81c
# [youtube] U9vZjYmt81c: Downloading webpage
# [youtube] U9vZjYmt81c: Downloading tv downgraded player API JSON
# [youtube] U9vZjYmt81c: Downloading web safari player API JSON
# [youtube] U9vZjYmt81c: Downloading m3u8 information
# [info] U9vZjYmt81c: Downloading 1 format(s): 301-13
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 12
# [download] Destination: data\raw_videos\knowledge Distillation_U9vZjYmt81c.mp4
# [download] fragment not found; Skipping fragment 1 ...
# [download] fragment not found; Skipping fragment 2 ...
# [download] fragment not found; Skipping fragment 3 ...
# [download] fragment not found; Skipping fragment 4 ...
# [download] fragment not found; Skipping fragment 5 ...
# [download] fragment not found; Skipping fragment 6 ...
# [download] fragment not found; Skipping fragment 7 ...
# [download] fragment not found; Skipping fragment 8 ...
# [download] fragment not found; Skipping fragment 9 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 140
#     137 format_id = user_choice if user_choice else None
#     139 # 3. 执行下载
# --> 140 download_youtube_video(test_url, cookies_path, format_id)
#
# Cell In[1], line 109, in download_youtube_video(url, cookies_file, format_id)
#     106 print(f"使用cookies文件：{cookies_file}")
#     108 with yt_dlp.YoutubeDL(ydl_opts) as ydl:
# --> 109     ydl.download([url])
#     111 print("\n下载完成！文件保存至：", output_dir)
#     112 return True
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3662, in YoutubeDL.download(self, url_list)
#    3659     raise SameFileError(outtmpl)
#    3661 for url in url_list:
# -> 3662     self.__download_wrapper(self.extract_info)(
#    3663         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3665 return self._download_retcode
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3635, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3632 @functools.wraps(func)
#    3633 def wrapper(*args, **kwargs):
#    3634     try:
# -> 3635         res = func(*args, **kwargs)
#    3636     except CookieLoadError:
#    3637         raise
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1685, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1683             raise ExistingVideoReached
#    1684         break
# -> 1685     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1686 else:
#    1687     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1696, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1694 while True:
#    1695     try:
# -> 1696         return func(self, *args, **kwargs)
#    1697     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1698         raise
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1852, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1850 if process:
#    1851     self._wait_for_video(ie_result)
# -> 1852     return self.process_ie_result(ie_result, download, extra_info)
#    1853 else:
#    1854     return ie_result
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1911, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1909 if result_type == 'video':
#    1910     self.add_extra_info(ie_result, extra_info)
# -> 1911     ie_result = self.process_video_result(ie_result, download=download)
#    1912     self._raise_pending_errors(ie_result)
#    1913     additional_urls = (ie_result or {}).get('additional_urls')
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3089, in YoutubeDL.process_video_result(self, info_dict, download)
#    3087 downloaded_formats.append(new_info)
#    3088 try:
# -> 3089     self.process_info(new_info)
#    3090 except MaxDownloadsReached:
#    3091     max_downloads_reached = True
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:189, in _catch_unsafe_extension_error.<locals>.wrapper(self, *args, **kwargs)
#     186 @functools.wraps(func)
#     187 def wrapper(self, *args, **kwargs):
#     188     try:
# --> 189         return func(self, *args, **kwargs)
#     190     except _UnsafeExtensionError as error:
#     191         self.report_error(
#     192             f'The extracted extension ({error.extension!r}) is unusual '
#     193             'and will be skipped for safety reasons. '
#     194             f'If you believe this is an error{bug_reports_message(",")}')
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3536, in YoutubeDL.process_info(self, info_dict)
#    3532 dl_filename = existing_video_file(full_filename, temp_filename)
#    3533 if dl_filename is None or dl_filename == temp_filename:
#    3534     # dl_filename == temp_filename could mean that the file was partially downloaded with --no-part.
#    3535     # So we should try to resume the download
# -> 3536     success, real_download = self.dl(temp_filename, info_dict)
#    3537     info_dict['__real_download'] = real_download
#    3538 else:
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3278, in YoutubeDL.dl(self, name, info, subtitle, test)
#    3276 if new_info.get('http_headers') is None:
#    3277     new_info['http_headers'] = self._calc_headers(new_info)
# -> 3278 return fd.download(name, new_info, subtitle)
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\downloader\common.py:480, in FileDownloader.download(self, filename, info_dict, subtitle)
#     477     self.to_screen(f'[download] Sleeping {sleep_interval:.2f} seconds {sleep_note}...')
#     478     time.sleep(sleep_interval)
# --> 480 ret = self.real_download(filename, info_dict)
#     481 self._finish_multiline_status()
#     482 return ret, True
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\downloader\hls.py:409, in HlsFD.real_download(self, filename, info_dict)
#     406         self.download_and_append_fragments(
#     407             ctx, fragments, info_dict, pack_func=pack_fragment, finish_func=fin_fragments)
#     408 else:
# --> 409     return self.download_and_append_fragments(ctx, fragments, info_dict)
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\downloader\fragment.py:513, in FragmentFD.download_and_append_fragments(self, ctx, fragments, info_dict, is_fatal, pack_func, finish_func, tpe, interrupt_trigger)
#     511     break
#     512 try:
# --> 513     download_fragment(fragment, ctx)
#     514     result = append_fragment(
#     515         decrypt_fragment(fragment, self._read_fragment(ctx)), fragment['frag_index'], ctx)
#     516 except KeyboardInterrupt:
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\downloader\fragment.py:462, in FragmentFD.download_and_append_fragments.<locals>.download_fragment(fragment, ctx)
#     460 try:
#     461     ctx['fragment_count'] = fragment.get('fragment_count')
# --> 462     if not self._download_fragment(
#     463             ctx, fragment['url'], info_dict, headers, info_dict.get('request_data')):
#     464         return
#     465 except (HTTPError, IncompleteRead) as err:
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\downloader\fragment.py:124, in FragmentFD._download_fragment(self, ctx, frag_url, info_dict, headers, request_data)
#     121     frag_resume_len = self.filesize_or_none(self.temp_name(fragment_filename))
#     122 fragment_info_dict['frag_resume_len'] = ctx['frag_resume_len'] = frag_resume_len
# --> 124 success, _ = ctx['dl'].download(fragment_filename, fragment_info_dict)
#     125 if not success:
#     126     return False
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\downloader\common.py:480, in FileDownloader.download(self, filename, info_dict, subtitle)
#     477     self.to_screen(f'[download] Sleeping {sleep_interval:.2f} seconds {sleep_note}...')
#     478     time.sleep(sleep_interval)
# --> 480 ret = self.real_download(filename, info_dict)
#     481 self._finish_multiline_status()
#     482 return ret, True
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\downloader\http.py:362, in HttpFD.real_download(self, filename, info_dict)
#     360 for retry in RetryManager(self.params.get('retries'), self.report_retry):
#     361     try:
# --> 362         establish_connection()
#     363         return download()
#     364     except RetryDownload as err:
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\downloader\http.py:119, in HttpFD.real_download.<locals>.establish_connection()
#     117 # Establish connection
#     118 try:
# --> 119     ctx.data = self.ydl.urlopen(request)
#     120     # When trying to resume, Content-Range HTTP header of response has to be checked
#     121     # to match the value of requested Range HTTP header. This is due to a webservers
#     122     # that don't support resuming and serve a whole file with no Content-Range
#     123     # set in response despite of requested Range (see
#     124     # https://github.com/ytdl-org/youtube-dl/issues/6057#issuecomment-126129799)
#     125     if has_range:
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\YoutubeDL.py:4252, in YoutubeDL.urlopen(self, req)
#    4249 clean_headers(req.headers)
#    4251 try:
# -> 4252     return self._request_director.send(req)
#    4253 except NoSupportingHandlers as e:
#    4254     for ue in e.unsupported_errors:
#    4255         # FIXME: This depends on the order of errors.
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\networking\common.py:117, in RequestDirector.send(self, request)
#     115 self._print_verbose(f'Sending request via "{handler.RH_NAME}"')
#     116 try:
# --> 117     response = handler.send(request)
#     118 except RequestError:
#     119     raise
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\networking\_helper.py:194, in wrap_request_errors.<locals>.wrapper(self, *args, **kwargs)
#     191 @functools.wraps(func)
#     192 def wrapper(self, *args, **kwargs):
#     193     try:
# --> 194         return func(self, *args, **kwargs)
#     195     except RequestError as e:
#     196         if e.handler is None:
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\networking\common.py:359, in RequestHandler.send(self, request)
#     357 if not isinstance(request, Request):
#     358     raise TypeError('Expected an instance of Request')
# --> 359 return self._send(request)
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\yt_dlp\networking\_requests.py:324, in RequestsRH._send(self, request)
#     318 session = self._get_instance(
#     319     cookiejar=self._get_cookiejar(request),
#     320     legacy_ssl_support=request.extensions.get('legacy_ssl'),
#     321 )
#     323 try:
# --> 324     requests_res = session.request(
#     325         method=request.method,
#     326         url=request.url,
#     327         data=request.data,
#     328         headers=headers,
#     329         timeout=self._calculate_timeout(request),
#     330         proxies=self._get_proxies(request),
#     331         allow_redirects=True,
#     332         stream=True,
#     333     )
#     335 except requests.exceptions.TooManyRedirects as e:
#     336     max_redirects_exceeded = True
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\urllib3\connectionpool.py:773, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     771 if self.proxy is not None and http_tunnel_required and conn.is_closed:
#     772     try:
# --> 773         self._prepare_proxy(conn)
#     774     except (BaseSSLError, OSError, SocketTimeout) as e:
#     775         self._raise_timeout(
#     776             err=e, url=self.proxy.url, timeout_value=conn.timeout
#     777         )
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1034     tunnel_scheme = "http"
#    1036 conn.set_tunnel(
#    1037     scheme=tunnel_scheme,
#    1038     host=self._tunnel_host,
#    1039     port=self.port,
#    1040     headers=self.proxy_headers,
#    1041 )
# -> 1042 conn.connect()
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
#     793     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     794     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 796     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     797         sock=sock,
#     798         cert_reqs=self.cert_reqs,
#     799         ssl_version=self.ssl_version,
#     800         ssl_minimum_version=self.ssl_minimum_version,
#     801         ssl_maximum_version=self.ssl_maximum_version,
#     802         ca_certs=self.ca_certs,
#     803         ca_cert_dir=self.ca_cert_dir,
#     804         ca_cert_data=self.ca_cert_data,
#     805         cert_file=self.cert_file,
#     806         key_file=self.key_file,
#     807         key_password=self.key_password,
#     808         server_hostname=server_hostname_rm_dot,
#     809         ssl_context=self.ssl_context,
#     810         tls_in_tls=tls_in_tls,
#     811         assert_hostname=self.assert_hostname,
#     812         assert_fingerprint=self.assert_fingerprint,
#     813     )
#     814     self.sock = sock_and_verified.socket
#     816 # If an error occurs during connection/handshake we may need to release
#     817 # our lock so another connection can probe the origin.
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\urllib3\connection.py:975, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     972     if is_ipaddress(normalized):
#     973         server_hostname = normalized
# --> 975 ssl_sock = ssl_wrap_socket(
#     976     sock=sock,
#     977     keyfile=key_file,
#     978     certfile=cert_file,
#     979     key_password=key_password,
#     980     ca_certs=ca_certs,
#     981     ca_cert_dir=ca_cert_dir,
#     982     ca_cert_data=ca_cert_data,
#     983     server_hostname=server_hostname,
#     984     ssl_context=context,
#     985     tls_in_tls=tls_in_tls,
#     986 )
#     988 try:
#     989     if assert_fingerprint:
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\urllib3\util\ssl_.py:483, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     479         context.load_cert_chain(certfile, keyfile, key_password)
#     481 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 483 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     484 return ssl_sock
#
# File d:\learning\project\youtube2tiktok\.venv\Lib\site-packages\urllib3\util\ssl_.py:527, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     524     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     525     return SSLTransport(sock, ssl_context, server_hostname)
# --> 527 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.12-windows-x86_64-none\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.12-windows-x86_64-none\Lib\ssl.py:1104, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1101             if timeout == 0.0:
#    1102                 # non-blocking
#    1103                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1104             self.do_handshake()
#    1105 except:
#    1106     try:
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.12-windows-x86_64-none\Lib\ssl.py:1382, in SSLSocket.do_handshake(self, block)
#    1380     if timeout == 0.0 and block:
#    1381         self.settimeout(None)
# -> 1382     self._sslobj.do_handshake()
#    1383 finally:
#    1384     self.settimeout(timeout)
#
# KeyboardInterrupt:
